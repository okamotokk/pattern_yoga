# %%
#LLMs[1][2][3] are used to create this code.
#[1] OpenAI. GPT-4o. (2025). Open AI. [Online]. Available: https://chatgpt.com/?model=gpt-4o
#[2] Google. 2.5 pro. (2025). Google. [Online] Available: https://gemini.google.com/app?hl=ja 
#[3] GitHub. GitHub Copilot. (2025). GitHub. [Online].

# %%
# %cd /content/drive/MyDrive/works/pattern/ # pleae change this code depens on your environment
# Out:
# /content/drive/MyDrive/works/pattern

# %%
# !pip install japanize-matplotlib

# %%
# --- 1. ライブラリのインポート ---
import json
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# import japanize_matplotlib
from PIL import Image, ImageOps
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import EfficientNetV2B0

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, f1_score

# %%
# --- 2. データの読み込みと特徴量エンジニアリング ---

# 2.1 データの読み込みと統合 (★複合エラーのJSONを追加)
json_files = {
    'good': './point_data/good.json',
    'error_hiza': './point_data/hiza.json',
    'error_ude': './point_data/ude.json',
    'error_kakato': './point_data/kakato.json',
    'hiza_kakato': './point_data/hiza_kakato.json', # 追加
    'ude_kakato': './point_data/ude_kakato.json',   # 追加
    'ude_hiza': './point_data/ude_hiza.json'       # 追加
}
all_data = []
for label, file_path in json_files.items():
    try:
        with open(file_path, 'r') as f:
            data = json.load(f)
            for item in data:
                item['source'] = label
            all_data.extend(data)
    except FileNotFoundError:
        print(f"警告: ファイルが見つかりませんでした: {file_path}")

df = pd.DataFrame(all_data)
print("--- データ読み込み完了 ---")
print(f"合計データ数: {len(df)}")
print(df['source'].value_counts())


# 2.2 特徴量計算関数の定義 (変更なし)
def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    ba, bc = a - b, c - b
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))
    return np.degrees(angle)

def extract_final_features(landmarks):
    # (この関数の中身は変更なし)
    coords = {lm: [data['x'], data['y'], data['z']] for lm, data in landmarks.items()}
    if landmarks.get('LEFT_KNEE') and landmarks.get('RIGHT_KNEE'):
        if coords['LEFT_KNEE'][0] > coords['RIGHT_KNEE'][0]: front, rear = 'LEFT', 'RIGHT'
        else: front, rear = 'RIGHT', 'LEFT'
    else: front, rear = 'LEFT', 'RIGHT'

    shoulder_center = (np.array(coords.get('LEFT_SHOULDER', [0,0,0])) + np.array(coords.get('RIGHT_SHOULDER', [0,0,0]))) / 2
    hip_center = (np.array(coords.get('LEFT_HIP', [0,0,0])) + np.array(coords.get('RIGHT_HIP', [0,0,0]))) / 2
    wrist_center = (np.array(coords.get('LEFT_WRIST', [0,0,0])) + np.array(coords.get('RIGHT_WRIST', [0,0,0]))) / 2
    ankle_center = (np.array(coords.get(f'{front}_ANKLE', [0,0,0])) + np.array(coords.get(f'{rear}_ANKLE', [0,0,0]))) / 2
    front_knee_angle = calculate_angle(coords.get(f'{front}_HIP', [0,0,0]), coords.get(f'{front}_KNEE', [0,0,0]), coords.get(f'{front}_ANKLE', [0,0,0]))
    rear_knee_angle = calculate_angle(coords.get(f'{rear}_HIP', [0,0,0]), coords.get(f'{rear}_KNEE', [0,0,0]), coords.get(f'{rear}_ANKLE', [0,0,0]))
    torso_vector = shoulder_center - hip_center
    vertical_vector = np.array([0, -1, 0])
    torso_tilt_angle = calculate_angle(hip_center + vertical_vector, hip_center, shoulder_center)
    arm_elevation_angle = calculate_angle(hip_center, shoulder_center, wrist_center)
    knee_dev_x = coords.get(f'{front}_KNEE', [0,0,0])[0] - coords.get(f'{front}_ANKLE', [0,0,0])[0]
    leg_height = abs(coords.get(f'{front}_ANKLE', [0,0,0])[1] - coords.get(f'{front}_KNEE', [0,0,0])[1])
    knee_forward_deviation = knee_dev_x / leg_height if leg_height != 0 else 0
    pose_span_x = abs(coords.get(f'{front}_ANKLE', [0,0,0])[0] - coords.get(f'{rear}_ANKLE', [0,0,0])[0])
    body_height = abs(shoulder_center[1] - ankle_center[1])
    pose_span_ratio = pose_span_x / body_height if body_height != 0 else 0
    foot_vec = np.array(coords.get(f'{rear}_FOOT_INDEX', [0,0,0])) - np.array(coords.get(f'{rear}_HEEL', [0,0,0]))
    rear_foot_tilt_angle = np.arctan2(abs(foot_vec[1]), foot_vec[0]) * 180.0 / np.pi
    return pd.Series([front_knee_angle, rear_knee_angle, torso_tilt_angle, arm_elevation_angle, knee_forward_deviation, pose_span_ratio, rear_foot_tilt_angle])


# --- 2.3 特徴量とパス、ラベルをデータフレームに追加 (最終修正版) ---

feature_names = ['front_knee_angle', 'rear_knee_angle', 'torso_tilt_angle', 'arm_elevation_angle', 'knee_forward_deviation', 'pose_span_ratio', 'rear_foot_tilt_angle']
error_labels = ['error_hiza', 'error_ude', 'error_kakato']

# 特徴量の計算
df[feature_names] = df['landmarks'].apply(extract_final_features)

# マルチラベルの作成
df['error_hiza'] = df['source'].str.contains('hiza').astype(int)
df['error_ude'] = df['source'].str.contains('ude').astype(int)
df['error_kakato'] = df['source'].str.contains('kakato').astype(int)


def get_correct_path_final(row):
    """
    【最終決定版】文字列操作で確実にパスを組み立てる関数
    """
    base_image_dir = Path('./image_data')

    # 1. 'source'列から実際のフォルダ名を取得
    #    'error_'という接頭辞を削除する
    category_folder = row['source'].replace('error_', '')

    # 2. 元のパス文字列を取得し、バックスラッシュをスラッシュに強制的に置換
    original_path_str = str(row['image_path'])
    normalized_path_str = original_path_str.replace('\\', '/')

    # 3. '/'で分割し、最後の要素（ファイル名）だけを取得
    file_name = normalized_path_str.split('/')[-1]

    # 4. 正しいパスを組み立てる
    # 例: './image_data' / 'good' / 'good_001.jpg'
    return str(base_image_dir / category_folder / file_name)

# ★★★★★ 新しい関数で、'correct_path'列を正しく作成 ★★★★★
df['correct_path'] = df.apply(get_correct_path_final, axis=1)

print("\n--- 【最終修正版】のロジックで、特徴量とパスの準備を更新しました ---")

# 正しくパスが作られているか、いくつかの例で確認
print("\n生成されたパスの例:")
try:
    print(df.loc[df['source'] == 'good', 'correct_path'].iloc[0])
    print(df.loc[df['source'] == 'error_ude', 'correct_path'].iloc[0])
    if 'hiza_kakato' in df['source'].unique():
        print(df.loc[df['source'] == 'hiza_kakato', 'correct_path'].iloc[0])
except IndexError:
    print("データが見つかりませんでした。")
# Out:
# --- データ読み込み完了 ---
# 合計データ数: 500
# source
# good            80
# error_hiza      80
# error_ude       80
# error_kakato    80
# hiza_kakato     60
# ude_kakato      60
# ude_hiza        60
# Name: count, dtype: int64
#
# --- 【最終修正版】のロジックで、特徴量とパスの準備を更新しました ---
#
# 生成されたパスの例:
# image_data/good/good_001.jpg
# image_data/ude/ude_001.jpg
# image_data/hiza_kakato/hiza_kakato_001.jpg

# %%
# --- 3. データセットの分割とスケーリング ---

# 3.1 訓練データとテストデータに分割
train_df, test_df = train_test_split(
    df,
    test_size=0.15,
    random_state=42,
    stratify=df['source']
)
X_train = train_df[feature_names]
y_train = train_df[error_labels]
X_test = test_df[feature_names]
y_test = test_df[error_labels]
print("\n--- データ分割完了 ---")
print(f"訓練データ数: {len(train_df)}, テストデータ数: {len(test_df)}")


# 3.2 特徴量のスケーリング (重要)
scaler = StandardScaler()
# 訓練データ"のみ"を使ってスケーリングの基準を学習
scaler.fit(X_train)
# 学習した基準で訓練・テストデータを変換
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
print("\n--- データスケーリング完了 ---")
# Out:
# --- データ分割完了 ---
# 訓練データ数: 425, テストデータ数: 75
#
# --- データスケーリング完了 ---

# %%
# --- 4. モデルA（門番・Autoencoder）の学習と可視化 ---

# 4.1 学習データの準備（良いポーズのみ）
# is_good_pose_train はステップ3でy_trainから計算可能ですが、
# 可視化のためにここで再定義しておくと分かりやすいです。
is_good_pose_train = train_df['source'] == 'good'
X_train_good_scaled = X_train_scaled[is_good_pose_train]

# 4.2 Autoencoderモデルの構築
input_dim = X_train_good_scaled.shape[1]
autoencoder = Sequential([
    Input(shape=(input_dim,)),
    Dense(8, activation='relu'),
    Dense(3, activation='relu'),
    Dense(8, activation='relu'),
    Dense(input_dim)
])
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
print("\n--- モデルA (Autoencoder) の学習開始 ---")

# 4.3 学習
autoencoder_history = autoencoder.fit(
    X_train_good_scaled, X_train_good_scaled,
    epochs=200,
    batch_size=16,
    shuffle=True,
    validation_split=0.1,
    verbose=1 # 学習の進捗を表示
)
print("--- 学習完了 ---")


# ★★★★★ ここからが可視化コードです ★★★★★

# 4.4 学習曲線の可視化
print("\n--- モデルA 学習曲線のプロット ---")
history_df = pd.DataFrame(autoencoder_history.history)
plt.figure(figsize=(10, 5))
plt.plot(history_df['loss'], label='Training Loss')
plt.plot(history_df['val_loss'], label='Validation Loss')
plt.title('Model A (Autoencoder) Learning Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# --- 4.5 再構成誤差の分布の可視化と、閾値T1の決定 (新基準版) ---

print("\n--- モデルA 再構成誤差の分布 ---")
# 全ての訓練データで誤差を計算 (この部分は変更なし)
reconstructions = autoencoder.predict(X_train_scaled, verbose=0)
mse = np.mean(np.power(X_train_scaled - reconstructions, 2), axis=1)

is_good_pose_train = train_df['source'] == 'good'
df_error = pd.DataFrame({'reconstruction_error': mse, 'is_good': is_good_pose_train.values})


# ★★★★★ ここからが新しい閾値の計算ロジック ★★★★★

# 1. 「悪いポーズ」の誤差だけを抽出
# is_good_pose_trainがFalseのものが悪いポーズ
mse_bad_poses = mse[~is_good_pose_train.values]

# 2. 悪いポーズの95パーセンタイル点を閾値とする
T1_threshold = np.percentile(mse_bad_poses, 98)

# ★★★★★ 修正はここまで ★★★★★


# 可視化（変更なし）
plt.figure(figsize=(12, 6))
sns.histplot(data=df_error, x='reconstruction_error', hue='is_good', kde=True, bins=50)
plt.title('Model A: Reconstruction Error Distribution (New Threshold)')
plt.axvline(T1_threshold, color='r', linestyle='--', linewidth=2, label=f'Threshold (T1) = {T1_threshold:.4f}')
plt.legend()
plt.show()

print(f"\n【新基準】で決定された異常検知の閾値 (T1): {T1_threshold:.6f}")
# T1_threshold = 3.129695
# Out:
# --- モデルA (Autoencoder) の学習開始 ---
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.7631 - val_loss: 0.5976
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7354 - val_loss: 0.5861
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7082 - val_loss: 0.5749
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6513 - val_loss: 0.5641
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7292 - val_loss: 0.5534
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6874 - val_loss: 0.5427
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5784 - val_loss: 0.5322
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.7578 - val_loss: 0.5217
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6761 - val_loss: 0.5116
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6673 - val_loss: 0.5018
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6609 - val_loss: 0.4921
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5991 - val_loss: 0.4823
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5558 - val_loss: 0.4728
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6206 - val_loss: 0.4637
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6328 - val_loss: 0.4545
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6126 - val_loss: 0.4457
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6548 - val_loss: 0.4371
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6424 - val_loss: 0.4285
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6246 - val_loss: 0.4201
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5909 - val_loss: 0.4119
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5888 - val_loss: 0.4037
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5724 - val_loss: 0.3957
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5777 - val_loss: 0.3877
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5327 - val_loss: 0.3801
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5157 - val_loss: 0.3725
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5680 - val_loss: 0.3651
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5277 - val_loss: 0.3580
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5656 - val_loss: 0.3511
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5058 - val_loss: 0.3443
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5360 - val_loss: 0.3377
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4933 - val_loss: 0.3314
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5929 - val_loss: 0.3255
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5337 - val_loss: 0.3194
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5303 - val_loss: 0.3134
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4720 - val_loss: 0.3075
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4437 - val_loss: 0.3019
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4442 - val_loss: 0.2960
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5079 - val_loss: 0.2903
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4144 - val_loss: 0.2849
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4479 - val_loss: 0.2796
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5362 - val_loss: 0.2744
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5065 - val_loss: 0.2693
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5175 - val_loss: 0.2643
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4660 - val_loss: 0.2595
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3871 - val_loss: 0.2548
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4151 - val_loss: 0.2501
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4925 - val_loss: 0.2457
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5101 - val_loss: 0.2412
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4846 - val_loss: 0.2367
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4969 - val_loss: 0.2323
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4167 - val_loss: 0.2281
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4452 - val_loss: 0.2241
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4580 - val_loss: 0.2199
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3469 - val_loss: 0.2162
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4606 - val_loss: 0.2124
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3840 - val_loss: 0.2089
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3680 - val_loss: 0.2053
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4847 - val_loss: 0.2020
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3155 - val_loss: 0.1988
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3789 - val_loss: 0.1956
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4490 - val_loss: 0.1928
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4510 - val_loss: 0.1899
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3398 - val_loss: 0.1871
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4614 - val_loss: 0.1845
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3163 - val_loss: 0.1819
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3118 - val_loss: 0.1794
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3836 - val_loss: 0.1770
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4229 - val_loss: 0.1746
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3361 - val_loss: 0.1725
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3740 - val_loss: 0.1704
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3948 - val_loss: 0.1684
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3648 - val_loss: 0.1663
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3515 - val_loss: 0.1645
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3034 - val_loss: 0.1625
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3288 - val_loss: 0.1607
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4303 - val_loss: 0.1591
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3756 - val_loss: 0.1576
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2932 - val_loss: 0.1562
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3454 - val_loss: 0.1549
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3056 - val_loss: 0.1539
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3349 - val_loss: 0.1527
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4158 - val_loss: 0.1515
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3688 - val_loss: 0.1505
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4034 - val_loss: 0.1496
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3345 - val_loss: 0.1486
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3154 - val_loss: 0.1478
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2712 - val_loss: 0.1472
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2766 - val_loss: 0.1467
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3721 - val_loss: 0.1462
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2841 - val_loss: 0.1458
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3073 - val_loss: 0.1453
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3377 - val_loss: 0.1447
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3166 - val_loss: 0.1443
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4010 - val_loss: 0.1438
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3316 - val_loss: 0.1440
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3146 - val_loss: 0.1440
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2726 - val_loss: 0.1443
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2962 - val_loss: 0.1445
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2412 - val_loss: 0.1444
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2663 - val_loss: 0.1444
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3105 - val_loss: 0.1444
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3317 - val_loss: 0.1445
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3397 - val_loss: 0.1448
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3544 - val_loss: 0.1447
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2637 - val_loss: 0.1451
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2526 - val_loss: 0.1456
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2581 - val_loss: 0.1463
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2633 - val_loss: 0.1473
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3237 - val_loss: 0.1486
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3738 - val_loss: 0.1493
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2491 - val_loss: 0.1502
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3146 - val_loss: 0.1509
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2597 - val_loss: 0.1509
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2359 - val_loss: 0.1512
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2829 - val_loss: 0.1522
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2798 - val_loss: 0.1522
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2502 - val_loss: 0.1520
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2304 - val_loss: 0.1519
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2707 - val_loss: 0.1519
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2410 - val_loss: 0.1514
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2370 - val_loss: 0.1510
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2825 - val_loss: 0.1512
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2821 - val_loss: 0.1514
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3539 - val_loss: 0.1515
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3075 - val_loss: 0.1521
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3083 - val_loss: 0.1521
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2769 - val_loss: 0.1518
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3029 - val_loss: 0.1512
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2937 - val_loss: 0.1514
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3455 - val_loss: 0.1512
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3330 - val_loss: 0.1507
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2561 - val_loss: 0.1505
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2319 - val_loss: 0.1508
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2693 - val_loss: 0.1509
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2617 - val_loss: 0.1508
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2197 - val_loss: 0.1506
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2599 - val_loss: 0.1503
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2454 - val_loss: 0.1505
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3057 - val_loss: 0.1508
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2444 - val_loss: 0.1506
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2419 - val_loss: 0.1500
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2657 - val_loss: 0.1498
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3583 - val_loss: 0.1503
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2559 - val_loss: 0.1502
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2201 - val_loss: 0.1505
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2762 - val_loss: 0.1508
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2575 - val_loss: 0.1508
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2434 - val_loss: 0.1506
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3373 - val_loss: 0.1498
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2526 - val_loss: 0.1500
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2198 - val_loss: 0.1500
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3286 - val_loss: 0.1500
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2254 - val_loss: 0.1492
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3592 - val_loss: 0.1493
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2985 - val_loss: 0.1490
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2955 - val_loss: 0.1487
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2660 - val_loss: 0.1486
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2902 - val_loss: 0.1494
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2828 - val_loss: 0.1492
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2217 - val_loss: 0.1494
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2806 - val_loss: 0.1486
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2832 - val_loss: 0.1488
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3543 - val_loss: 0.1483
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2977 - val_loss: 0.1480
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2338 - val_loss: 0.1484
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2310 - val_loss: 0.1481
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3150 - val_loss: 0.1479
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2921 - val_loss: 0.1477
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2090 - val_loss: 0.1462
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2814 - val_loss: 0.1452
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3114 - val_loss: 0.1460
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2525 - val_loss: 0.1468
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3190 - val_loss: 0.1465
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2415 - val_loss: 0.1463
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2208 - val_loss: 0.1453
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2624 - val_loss: 0.1441
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2489 - val_loss: 0.1433
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2416 - val_loss: 0.1443
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2445 - val_loss: 0.1439
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2744 - val_loss: 0.1438
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2733 - val_loss: 0.1442
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3066 - val_loss: 0.1438
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2706 - val_loss: 0.1428
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2205 - val_loss: 0.1427
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3236 - val_loss: 0.1435
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2933 - val_loss: 0.1429
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2195 - val_loss: 0.1433
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3426 - val_loss: 0.1427
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2509 - val_loss: 0.1420
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2811 - val_loss: 0.1416
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2115 - val_loss: 0.1415
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2097 - val_loss: 0.1410
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2747 - val_loss: 0.1408
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2440 - val_loss: 0.1407
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2828 - val_loss: 0.1405
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2323 - val_loss: 0.1398
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2047 - val_loss: 0.1395
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2013 - val_loss: 0.1396
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2219 - val_loss: 0.1397
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2996 - val_loss: 0.1404
# --- 学習完了 ---
#
# --- モデルA 学習曲線のプロット ---
# --- モデルA 再構成誤差の分布 ---
# 【新基準】で決定された異常検知の閾値 (T1): 3.611175

# %%
# --- 5. モデルB（MLPモデル：骨格特徴量のみ） ---

BATCH_SIZE = 16

def create_features_dataset(dataframe):
    scaled_feature_values = scaler.transform(dataframe[feature_names])
    features_data = scaled_feature_values.astype('float32')
    labels_data = dataframe[error_labels].values.astype('float32')
    features_ds = tf.data.Dataset.from_tensor_slices(features_data)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels_data)
    return tf.data.Dataset.zip((features_ds, labels_ds))

train_ds = create_features_dataset(train_df).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
test_ds = create_features_dataset(test_df).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
print("\n--- tf.dataパイプライン構築完了（特徴量のみ） ---")

# 5.2 モデルの構築（MLPのみ）
input_features = Input(shape=(len(feature_names),), name='features_input')
x = Dense(32, activation='relu')(input_features)
x = Dense(16, activation='relu')(x)
output = Dense(len(error_labels), activation='sigmoid', name='output')(x)
mlp_model = Model(inputs=input_features, outputs=output)
mlp_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 5.3 モデルの学習
print("\n--- モデルB (MLPモデル) の学習開始 ---")
history = mlp_model.fit(
    train_ds,
    epochs=50,
    validation_data=test_ds,
    verbose=1,
)
print("--- 学習完了 ---")

# 5.4 学習曲線のプロット
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.title("Model B (MLP) Training History")
plt.show()
# Out:
# --- tf.dataパイプライン構築完了（特徴量のみ） ---
#
# --- モデルB (MLPモデル) の学習開始 ---
# Epoch 1/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2429 - loss: 0.7028 - val_accuracy: 0.2800 - val_loss: 0.6657
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4021 - loss: 0.6378 - val_accuracy: 0.3600 - val_loss: 0.6287
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4682 - loss: 0.5922 - val_accuracy: 0.4133 - val_loss: 0.5984
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5340 - loss: 0.5525 - val_accuracy: 0.4667 - val_loss: 0.5679
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5557 - loss: 0.5129 - val_accuracy: 0.4933 - val_loss: 0.5353
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5488 - loss: 0.4734 - val_accuracy: 0.5467 - val_loss: 0.5009
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5591 - loss: 0.4370 - val_accuracy: 0.5600 - val_loss: 0.4723
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5664 - loss: 0.4066 - val_accuracy: 0.5467 - val_loss: 0.4465
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5554 - loss: 0.3808 - val_accuracy: 0.5733 - val_loss: 0.4235
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5558 - loss: 0.3590 - val_accuracy: 0.5733 - val_loss: 0.4065
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5577 - loss: 0.3416 - val_accuracy: 0.5867 - val_loss: 0.3941
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5660 - loss: 0.3284 - val_accuracy: 0.5867 - val_loss: 0.3855
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5673 - loss: 0.3187 - val_accuracy: 0.6000 - val_loss: 0.3793
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5818 - loss: 0.3114 - val_accuracy: 0.6000 - val_loss: 0.3746
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5848 - loss: 0.3056 - val_accuracy: 0.6000 - val_loss: 0.3714
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5917 - loss: 0.3007 - val_accuracy: 0.6000 - val_loss: 0.3685
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5917 - loss: 0.2965 - val_accuracy: 0.6000 - val_loss: 0.3660
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5900 - loss: 0.2929 - val_accuracy: 0.6000 - val_loss: 0.3637
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5927 - loss: 0.2897 - val_accuracy: 0.6000 - val_loss: 0.3618
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5932 - loss: 0.2866 - val_accuracy: 0.6000 - val_loss: 0.3600
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5932 - loss: 0.2837 - val_accuracy: 0.6133 - val_loss: 0.3582
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5986 - loss: 0.2810 - val_accuracy: 0.6133 - val_loss: 0.3567
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5986 - loss: 0.2784 - val_accuracy: 0.6133 - val_loss: 0.3554
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6004 - loss: 0.2760 - val_accuracy: 0.6267 - val_loss: 0.3539
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6001 - loss: 0.2740 - val_accuracy: 0.6267 - val_loss: 0.3530
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6001 - loss: 0.2720 - val_accuracy: 0.6267 - val_loss: 0.3522
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6008 - loss: 0.2703 - val_accuracy: 0.6267 - val_loss: 0.3514
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5962 - loss: 0.2686 - val_accuracy: 0.6267 - val_loss: 0.3509
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5962 - loss: 0.2669 - val_accuracy: 0.6267 - val_loss: 0.3507
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5994 - loss: 0.2653 - val_accuracy: 0.6267 - val_loss: 0.3502
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5994 - loss: 0.2637 - val_accuracy: 0.6267 - val_loss: 0.3499
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6018 - loss: 0.2623 - val_accuracy: 0.6267 - val_loss: 0.3497
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6018 - loss: 0.2610 - val_accuracy: 0.6267 - val_loss: 0.3496
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6018 - loss: 0.2597 - val_accuracy: 0.6267 - val_loss: 0.3493
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6018 - loss: 0.2584 - val_accuracy: 0.6267 - val_loss: 0.3494
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6038 - loss: 0.2573 - val_accuracy: 0.6267 - val_loss: 0.3495
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6075 - loss: 0.2561 - val_accuracy: 0.6267 - val_loss: 0.3491
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6075 - loss: 0.2549 - val_accuracy: 0.6267 - val_loss: 0.3492
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6075 - loss: 0.2537 - val_accuracy: 0.6267 - val_loss: 0.3494
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6069 - loss: 0.2525 - val_accuracy: 0.6267 - val_loss: 0.3493
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6045 - loss: 0.2514 - val_accuracy: 0.6267 - val_loss: 0.3496
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5985 - loss: 0.2502 - val_accuracy: 0.6267 - val_loss: 0.3491
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5985 - loss: 0.2490 - val_accuracy: 0.6267 - val_loss: 0.3496
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5958 - loss: 0.2478 - val_accuracy: 0.6267 - val_loss: 0.3492
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5958 - loss: 0.2467 - val_accuracy: 0.6267 - val_loss: 0.3494
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5958 - loss: 0.2455 - val_accuracy: 0.6267 - val_loss: 0.3494
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5969 - loss: 0.2444 - val_accuracy: 0.6267 - val_loss: 0.3489
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5972 - loss: 0.2432 - val_accuracy: 0.6133 - val_loss: 0.3493
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5972 - loss: 0.2420 - val_accuracy: 0.6133 - val_loss: 0.3494
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5969 - loss: 0.2408 - val_accuracy: 0.6133 - val_loss: 0.3492
# --- 学習完了 ---

# %%
# ==============================================================================
# --- 7. 動画によるリアルタイムフィードバックシステム (修正版) ---
# ==============================================================================
# !pip install mediapipe opencv-python
# !pip install tqdm # 進捗バーを表示するために追加
import cv2
import mediapipe as mp
import time
from tqdm import tqdm # 進捗バーを表示するために追加
from copy import deepcopy

print("\n--- 7. 動画フィードバックシステムの準備 ---")
# Out:
# Requirement already satisfied: mediapipe in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (0.10.21)
# Requirement already satisfied: opencv-python in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (4.11.0.86)
# Requirement already satisfied: absl-py in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (2.3.0)
# Requirement already satisfied: attrs>=19.1.0 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: jaxlib in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: matplotlib in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (3.10.3)
# Requirement already satisfied: numpy<2 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from jax->mediapipe) (0.5.1)
# Requirement already satisfied: opt_einsum in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from jax->mediapipe) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from matplotlib->mediapipe) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1
#
# --- 7. 動画フィードバックシステムの準備 ---

# %%
# ## 6. システム全体の最終性能評価
# ---
# ここでは、学習済みのモデルを使い、テストデータセット (`test_df`) に対する総合的な精度を評価します。

# %%
# 6.1 ヘルパー関数: フィードバックキーを予測ベクトルに変換
def key_to_vector(key):
    """フィードバックキー（例: "error_ude_hiza"）を多ラベルベクトル（例: [1, 1, 0]）に変換する。"""
    if key == "abnormal": return [1, 1, 1]
    hiza = 1 if 'hiza' in key else 0
    ude = 1 if 'ude' in key else 0
    kakato = 1 if 'kakato' in key else 0
    return [hiza, ude, kakato]

# 6.2 評価実行関数
def evaluate_model_on_test_set(test_dataframe):
    """
    テストデータセット全体を推論し、分類レポートを出力する。
    """
    print("\n--- 最終性能評価を開始します ---")
    all_predictions = []
    y_true = test_dataframe[error_labels].values

    for index, row in tqdm(test_dataframe.iterrows(), total=len(test_dataframe), desc="テストデータを評価中"):
        # 画像とランドマークを取得
        image_path = row['correct_path']
        image = cv2.imread(image_path)
        if image is None:
            all_predictions.append([0, 0, 0])
            continue
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        landmarks_3d = row['landmarks']

        # エラーを推論（動画処理で使う関数を再利用）
        feedback_key, _, _ = predict_pose_errors(image_rgb, landmarks_3d)

        # 推論結果をベクトルに変換
        pred_vector = key_to_vector(feedback_key)
        all_predictions.append(pred_vector)

    # 評価指標を計算して表示
    y_pred = np.array(all_predictions)
    print("\n--- 最終推論パイプライン 評価レポート ---")
    print(classification_report(y_true, y_pred, target_names=error_labels, zero_division=0))
    macro_f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
    print(f"\n最終的な総合評価 (Macro-Average F1 Score): {macro_f1:.4f}")
    return macro_f1

# %%
# 7.1 初期設定とヘルパー関数の定義

# --- 設定項目 ---
SKELETON_DRAW_HZ = 20
INFERENCE_HZ = 1
MODEL_B_THRESHOLD = 0.15

# MediaPipe Poseの準備
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose_detector = mp_pose.Pose(
    static_image_mode=False,
    model_complexity=1,
    enable_segmentation=False,
    min_detection_confidence=0.5
)
BODY_CONNECTIONS = set([c for c in mp_pose.POSE_CONNECTIONS if c[0] > 10 and c[1] > 10])

# --- ★★★ フィードバック用画像のパスを新しい定義に更新 ★★★ ---
feedback_image_paths = {
    "no_pose":         './feedback_images/01_no_pose.JPG',
    "perfect":         './feedback_images/02_perfect.JPG',
    "error_hiza":      './feedback_images/03_hiza.JPG',
    "error_ude":       './feedback_images/04_ude.JPG',
    "error_kakato":    './feedback_images/05_kakato.JPG',
    "error_ude_hiza":  './feedback_images/06_ude_hiza.JPG',
    "error_ude_kakato":'./feedback_images/07_ude_kakato.JPG',
    "error_hiza_kakato":'./feedback_images/08_hiza_kakato.JPG',
    "abnormal":        './feedback_images/09_abnormal.JPG' # 門番 or 3つ全てのエラー
}

# フィードバック画像を事前に読み込んでおく
feedback_images = {name: cv2.imread(path) for name, path in feedback_image_paths.items()}
# 画像が見つからない場合のエラー処理
if any(img is None for img in feedback_images.values()):
    print("警告: フィードバック画像の一部が見つかりません。パスとファイル名を確認してください。")
    dummy_img = np.zeros((480, 480, 3), dtype=np.uint8)
    cv2.putText(dummy_img, 'IMG NOT FOUND', (30, 240), cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), 3)
    feedback_images = {name: img if img is not None else dummy_img for name, img in feedback_images.items()}


# --- エラー箇所に対応するランドマークのインデックスを定義 ---
error_landmark_indices = {
    'hiza': [mp_pose.PoseLandmark.LEFT_KNEE.value],
    'ude': [mp_pose.PoseLandmark.LEFT_WRIST.value, mp_pose.PoseLandmark.LEFT_ELBOW.value, mp_pose.PoseLandmark.RIGHT_WRIST.value, mp_pose.PoseLandmark.RIGHT_ELBOW.value],
    'kakato': [mp_pose.PoseLandmark.LEFT_HEEL.value]
}
# Out:
# 警告: フィードバック画像の一部が見つかりません。パスとファイル名を確認してください。
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751802280.433478 3665615 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1751802280.526016 3742485 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.28.03), renderer: NVIDIA GeForce RTX 2080 Ti/PCIe/SSE2
# [ WARN:0@10354.847] global loadsave.cpp:268 findDecoder imread_('./feedback_images/01_no_pose.JPG'): can't open/read file: check file path/integrity
# [ WARN:0@10354.847] global loadsave.cpp:268 findDecoder imread_('./feedback_images/02_perfect.JPG'): can't open/read file: check file path/integrity
# [ WARN:0@10354.847] global loadsave.cpp:268 findDecoder imread_('./feedback_images/03_hiza.JPG'): can't open/read file: check file path/integrity
# [ WARN:0@10354.847] global loadsave.cpp:268 findDecoder imread_('./feedback_images/04_ude.JPG'): can't open/read file: check file path/integrity
# [ WARN:0@10354.847] global loadsave.cpp:268 findDecoder imread_('./feedback_images/05_kakato.JPG'): can't open/read file: check file path/integrity
# [ WARN:0@10354.848] global loadsave.cpp:268 findDecoder imread_('./feedback_images/06_ude_hiza.JPG'): can't open/read file: check file path/integrity
# [ WARN:0@10354.848] global loadsave.cpp:268 findDecoder imread_('./feedback_images/07_ude_kakato.JPG'): can't open/read file: check file path/integrity
# [ WARN:0@10354.848] global loadsave.cpp:268 findDecoder imread_('./feedback_images/08_hiza_kakato.JPG'): can't open/read file: check file path/integrity
# [ WARN:0@10354.848] global loadsave.cpp:268 findDecoder imread_('./feedback_images/09_abnormal.JPG'): can't open/read file: check file path/integrity
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1751802280.634537 3742451 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1751802280.691023 3742468 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
from mediapipe.framework.formats import landmark_pb2

def smooth_landmarks(current_landmarks, previous_landmarks, alpha=0.5):
    """
    ランドマークを時間的に平滑化（Exponential Moving Average）する。
    alpha: 平滑化の強さ。0に近いほど滑らか（遅延は大きい）、1に近いほど生のデータに近い。
    """
    if previous_landmarks is None:
        return current_landmarks

    smoothed_landmarks = landmark_pb2.NormalizedLandmarkList()

    for i in range(len(current_landmarks.landmark)):
        prev_lm = previous_landmarks.landmark[i]
        curr_lm = current_landmarks.landmark[i]

        smoothed_lm = smoothed_landmarks.landmark.add()
        smoothed_lm.x = alpha * curr_lm.x + (1.0 - alpha) * prev_lm.x
        smoothed_lm.y = alpha * curr_lm.y + (1.0 - alpha) * prev_lm.y
        smoothed_lm.z = alpha * curr_lm.z + (1.0 - alpha) * prev_lm.z
        smoothed_lm.visibility = curr_lm.visibility

    return smoothed_landmarks

# %%
# 7.2 描画およびリサイズ用ヘルパー関数 (このセクションは変更なし)

def draw_custom_landmarks(image, landmarks, connections, error_keys):
    """
    骨格を描画する関数。顔は非表示にし、エラー箇所は赤い円で囲む。
    """
    # ★★★ 修正点1：顔のランドマークの点を非表示にする処理 ★★★
    # 元のデータに影響を与えないよう、ディープコピーを作成
    landmarks_body_only = deepcopy(landmarks)
    # 顔のランドマーク（index 0～10）のvisibilityを0に設定して見えなくする
    for i in range(11):
        landmarks_body_only.landmark[i].visibility = 0

    # エラー箇所の特定（変更なし）
    error_indices_set = set()
    for key in error_keys:
        if key in error_landmark_indices:
            error_indices_set.update(error_landmark_indices[key])

    # 体の骨格を緑で描画（landmarks_body_onlyを使用）
    mp_drawing.draw_landmarks(
        image=image,
        landmark_list=landmarks_body_only, # 顔を非表示にしたデータを使用
        connections=connections,           # BODY_CONNECTIONSが渡される
        landmark_drawing_spec=mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=-1, circle_radius=4),
        connection_drawing_spec=mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2)
    )

    # エラー箇所を赤い円で上書き描画（変更なし）
    if landmarks:
        for idx in error_indices_set:
            # 元のlandmarkデータを使って位置を計算
            lm = landmarks.landmark[idx]
            h, w, _ = image.shape
            if lm.visibility > 0.5:
                cx, cy = int(lm.x * w), int(lm.y * h)
                cv2.circle(image, (cx, cy), 20, (0, 0, 255), 3)


def combine_videos(frame_left, frame_right):
    """
    左のフレームの高さに合わせて右のフレームをリサイズし、横に結合する。
    """
    h_left, w_left, _ = frame_left.shape
    h_right, w_right, _ = frame_right.shape

    scale = h_left / h_right
    new_w_right = int(w_right * scale)
    frame_right_resized = cv2.resize(frame_right, (new_w_right, h_left))

    combined_frame = np.concatenate((frame_left, frame_right_resized), axis=1)
    return combined_frame

# %%
# 7.3 推論パイプライン関数 (修正版)

def predict_pose_errors(frame, landmarks_3d):
    """
    1フレームとランドマーク情報から、エラー内容を推論する。（新しいキーに対応）
    """
    # 1. 特徴量抽出
    features = extract_final_features(landmarks_3d)
    features_scaled = scaler.transform([features])

    # 2. モデルA (Autoencoder) で異常検知
    reconstruction = autoencoder.predict(features_scaled, verbose=0)
    mse = np.mean(np.power(features_scaled - reconstruction, 2), axis=1)[0]

    if mse > T1_threshold:
        return "abnormal", mse, ['hiza', 'ude', 'kakato'] # abnormal時は全箇所をエラーとして表示

    # 3. モデルB (2系統モデル) でエラー分類


    predictions = mlp_model.predict(features_scaled, verbose=0)[0]
    pred_labels = (predictions > MODEL_B_THRESHOLD).astype(int)

    # 4. ★★★ フィードバックロジックを新しいキーに合わせて修正 ★★★
    error_keys = []
    if pred_labels[0]: error_keys.append('hiza')
    if pred_labels[1]: error_keys.append('ude')
    if pred_labels[2]: error_keys.append('kakato')

    num_errors = len(error_keys)
    feedback_key = ""

    if num_errors >= 3:
        feedback_key = "abnormal"
    elif num_errors == 2:
        if 'ude' in error_keys and 'hiza' in error_keys:
            feedback_key = "error_ude_hiza"
        elif 'ude' in error_keys and 'kakato' in error_keys:
            feedback_key = "error_ude_kakato"
        elif 'hiza' in error_keys and 'kakato' in error_keys:
            feedback_key = "error_hiza_kakato"
    elif num_errors == 1:
        feedback_key = f"error_{error_keys[0]}"
    else:
        feedback_key = "perfect"

    return feedback_key, mse, error_keys

# %%
# 7.4 動画処理のメイン実行関数 (修正版)

def process_video_with_feedback(input_video_path, output_video_path):
    """
    動画を読み込み、AIフィードバックを付けて新しい動画として保存する。（新しいキーに対応）
    """
    print(f"\n--- 動画処理開始: {input_video_path} ---")
    cap = cv2.VideoCapture(input_video_path)
    if not cap.isOpened():
        print(f"エラー: 動画ファイルが開けません: {input_video_path}")
        return

    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    out = None
    draw_interval = 1.0 / SKELETON_DRAW_HZ
    inference_interval = 1.0 / INFERENCE_HZ
    last_draw_time = -draw_interval
    last_inference_time = -inference_interval

    last_landmarks = None
    last_error_keys = []
    # ★★★ 初期状態のキーを 'perfect' に変更 ★★★
    current_feedback_key = "perfect"

    pbar = tqdm(total=total_frames, desc="Processing Video")

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        current_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000.0
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        if (current_time - last_draw_time) >= draw_interval:
            last_draw_time = current_time
            results = pose_detector.process(frame_rgb)
            if results.pose_landmarks:
                last_landmarks = results.pose_landmarks

        if (current_time - last_inference_time) >= inference_interval:
            last_inference_time = current_time
            if last_landmarks and results.pose_world_landmarks:
                landmarks_3d = {lm.name: {'x': data.x, 'y': data.y, 'z': data.z}
                                for lm, data in zip(mp_pose.PoseLandmark, results.pose_world_landmarks.landmark)}
                feedback_key, mse, error_keys = predict_pose_errors(frame_rgb, landmarks_3d)
                current_feedback_key = feedback_key
                last_error_keys = error_keys
            else:
                # ★★★ 骨格未検出時のキーを 'no_pose' に変更 ★★★
                current_feedback_key = "no_pose"
                last_error_keys = []

        annotated_image = frame.copy()
        if last_landmarks:
            draw_custom_landmarks(annotated_image, last_landmarks, BODY_CONNECTIONS, last_error_keys)

        feedback_image = feedback_images[current_feedback_key]
        combined_output_frame = combine_videos(annotated_image, feedback_image)

        if out is None:
            h, w, _ = combined_output_frame.shape
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_video_path, fourcc, fps, (w, h))

        out.write(combined_output_frame)
        pbar.update(1)

    cap.release()
    if out:
      out.release()
    pbar.close()
    print(f"--- 動画処理完了: {output_video_path} に保存しました ---")

# %%
# ## 8. 実行ブロック
# ---
# ここで、実行したい処理を選択します。

# %%
# --- 実行したい処理のコメントを外してください ---

# 【A】テストデータセット全体でモデルの最終性能を評価する場合
evaluate_model_on_test_set(test_df)
# Out:
# --- 最終性能評価を開始します ---
# テストデータを評価中:   0%|          | 0/75 [00:00<?, ?it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:   1%|▏         | 1/75 [00:00<00:13,  5.57it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:   3%|▎         | 2/75 [00:00<00:23,  3.08it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:   4%|▍         | 3/75 [00:00<00:17,  4.22it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:   5%|▌         | 4/75 [00:00<00:14,  4.96it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:   7%|▋         | 5/75 [00:01<00:18,  3.76it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:   8%|▊         | 6/75 [00:01<00:16,  4.27it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  11%|█         | 8/75 [00:01<00:15,  4.35it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  12%|█▏        | 9/75 [00:02<00:13,  4.87it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  13%|█▎        | 10/75 [00:02<00:12,  5.24it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  15%|█▍        | 11/75 [00:02<00:11,  5.67it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  16%|█▌        | 12/75 [00:02<00:10,  5.87it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  17%|█▋        | 13/75 [00:02<00:10,  6.15it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  19%|█▊        | 14/75 [00:02<00:09,  6.21it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  20%|██        | 15/75 [00:02<00:09,  6.52it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  21%|██▏       | 16/75 [00:03<00:09,  6.51it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  23%|██▎       | 17/75 [00:03<00:08,  6.62it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  24%|██▍       | 18/75 [00:03<00:08,  6.71it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  25%|██▌       | 19/75 [00:03<00:08,  6.61it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  27%|██▋       | 20/75 [00:03<00:11,  4.71it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  28%|██▊       | 21/75 [00:04<00:12,  4.19it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  29%|██▉       | 22/75 [00:04<00:11,  4.64it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  31%|███       | 23/75 [00:04<00:13,  3.80it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  32%|███▏      | 24/75 [00:04<00:11,  4.40it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  33%|███▎      | 25/75 [00:04<00:10,  4.94it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  35%|███▍      | 26/75 [00:05<00:08,  5.49it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  36%|███▌      | 27/75 [00:05<00:11,  4.25it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  37%|███▋      | 28/75 [00:05<00:10,  4.64it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  40%|████      | 30/75 [00:06<00:09,  4.58it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  41%|████▏     | 31/75 [00:06<00:08,  4.97it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  43%|████▎     | 32/75 [00:06<00:10,  4.02it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  44%|████▍     | 33/75 [00:06<00:09,  4.58it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  45%|████▌     | 34/75 [00:06<00:08,  5.07it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  47%|████▋     | 35/75 [00:07<00:07,  5.53it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  48%|████▊     | 36/75 [00:07<00:06,  6.00it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  49%|████▉     | 37/75 [00:07<00:06,  6.21it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  51%|█████     | 38/75 [00:07<00:08,  4.35it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  52%|█████▏    | 39/75 [00:08<00:09,  3.66it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  53%|█████▎    | 40/75 [00:08<00:10,  3.26it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  55%|█████▍    | 41/75 [00:08<00:08,  3.81it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  56%|█████▌    | 42/75 [00:08<00:07,  4.50it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  57%|█████▋    | 43/75 [00:08<00:06,  5.01it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  59%|█████▊    | 44/75 [00:09<00:07,  4.04it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  60%|██████    | 45/75 [00:09<00:06,  4.55it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  61%|██████▏   | 46/75 [00:09<00:05,  5.09it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  63%|██████▎   | 47/75 [00:09<00:06,  4.09it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  64%|██████▍   | 48/75 [00:10<00:05,  4.68it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  65%|██████▌   | 49/75 [00:10<00:06,  3.87it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  67%|██████▋   | 50/75 [00:10<00:07,  3.41it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  68%|██████▊   | 51/75 [00:10<00:06,  3.99it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  69%|██████▉   | 52/75 [00:11<00:06,  3.48it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  71%|███████   | 53/75 [00:11<00:06,  3.17it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  72%|███████▏  | 54/75 [00:11<00:05,  3.79it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  75%|███████▍  | 56/75 [00:12<00:04,  4.06it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  76%|███████▌  | 57/75 [00:12<00:04,  3.62it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  79%|███████▊  | 59/75 [00:12<00:03,  4.79it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  80%|████████  | 60/75 [00:13<00:02,  5.10it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  81%|████████▏ | 61/75 [00:13<00:02,  5.49it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  83%|████████▎ | 62/75 [00:13<00:02,  5.87it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  84%|████████▍ | 63/75 [00:13<00:02,  5.93it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  85%|████████▌ | 64/75 [00:13<00:01,  6.21it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  87%|████████▋ | 65/75 [00:13<00:01,  6.46it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  88%|████████▊ | 66/75 [00:13<00:01,  6.52it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  89%|████████▉ | 67/75 [00:14<00:01,  6.54it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  91%|█████████ | 68/75 [00:14<00:01,  4.57it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  92%|█████████▏| 69/75 [00:14<00:01,  3.76it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  93%|█████████▎| 70/75 [00:14<00:01,  4.37it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  95%|█████████▍| 71/75 [00:15<00:00,  4.84it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  96%|█████████▌| 72/75 [00:15<00:00,  4.00it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  97%|█████████▋| 73/75 [00:15<00:00,  4.63it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中:  99%|█████████▊| 74/75 [00:15<00:00,  5.09it/s]/home/mhoshino/anaconda3/envs/yoga/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# テストデータを評価中: 100%|██████████| 75/75 [00:15<00:00,  4.72it/s]
# --- 最終推論パイプライン 評価レポート ---
#               precision    recall  f1-score   support
#
#   error_hiza       0.72      0.93      0.81        30
#    error_ude       0.55      0.87      0.68        30
# error_kakato       0.65      1.00      0.79        30
#
#    micro avg       0.64      0.93      0.76        90
#    macro avg       0.64      0.93      0.76        90
# weighted avg       0.64      0.93      0.76        90
#  samples avg       0.60      0.79      0.66        90
#
#
# 最終的な総合評価 (Macro-Average F1 Score): 0.7588
# 0.7587975208112508
